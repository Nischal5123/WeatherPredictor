# %%
#importing libraries
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize']=(16,9)
plt.style.use('ggplot')
data=pd.read_csv('C:/Users/Nischal Aryal/MachineLearning/Weather_Analysis/xclara.csv')
print(data.shape)
data.head()
# Out:
# (3000, 2)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Temperature Difference</th>
#       <th>Pressure Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.072345</td>
#       <td>-3.241693</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17.936710</td>
#       <td>15.784810</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.083576</td>
#       <td>7.319176</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>11.120670</td>
#       <td>14.406780</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>23.711550</td>
#       <td>2.557729</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
data=pd.read_csv('C:/Users/Nischal Aryal/MachineLearning/Weather_Analysis/xclara.csv')
print(data.shape)
data.head()
# Out:
# (3000, 2)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Temperature Difference</th>
#       <th>Pressure Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2.072345</td>
#       <td>-3.241693</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17.936710</td>
#       <td>15.784810</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.083576</td>
#       <td>7.319176</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>11.120670</td>
#       <td>14.406780</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>23.711550</td>
#       <td>2.557729</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
#plotting cluster of data
f1=data ['Temperature Difference'].values
f2=data['Pressure Difference'].values
X=np.array(list(zip(f1,f2)))
plt.scatter(f1,f2,c='black',s=8)

# %%
#Euclidean Distance Calcultor
def dist(a,b,ax=1):
    return np.linalg.norm(a-b,axis=ax)

# %%
#Number of clsuters
k=3
#X coordinates of random centroids
C_x=np.random.randint(0,np.max(X)-20,size=k)

#Y coordinates of random centroids
C_y=np.random.randint(0,np.max(X)-20,size=k)
C=np.array(list(zip(C_x,C_y)), dtype=np.float32)
print(C)
# Out:
# [[48. 40.]
#  [66. 64.]
#  [39.  9.]]

# %%
#Plotting along with the Centroids
plt.scatter(f1,f2,c='#050505',s=7)
plt.scatter(C_x,C_y,marker='*',s=400,c='g')

#To store the value of centroid when it updates
C_old=np.zeros(C.shape)

#Clsuter labels(0,1,2)
clusters=np.zeros(len(X))

#Error Checking=Distance between new centroid and old centroid
error=dist(C,C_old,None)

#Loop will run till the error becomes zero
while error!=0 :
#Assigning each value to its closest cluster
    for i in range(len(X)):
        distances=dist(X[i],C)
        cluster=np.argmin(distances)
        clusters[i]=cluster
        #Storing the old centroid values
C_old=deepcopy(C)
#finding the new centroid by taking the average value
for i in range(k):
    points= [X[J] for j in range(len(x)) if clusters[j]==i]
    C[i]=np.mean(points,axis=0)
    error=dist(C,C_old,None)
colors=['r','g','b','y','c','m']
fig.ax=plt.subplots()

for i in range(k)
    points=np.array([X[J] for j in range(len(X)) if clusters[j]==i])
    ax.scatter(points[:,0],points[:,1],s=7,c=colors[i])
    ax.scatter(C[:,0],C[:,1],marker='*',s=400,c='#0505505

# %%
#To store the value of centroid when it updates
C_old=np.zeros(C.shape)

#Clsuter labels(0,1,2)
clusters=np.zeros(len(X))

#Error Checking=Distance between new centroid and old centroid
error=dist(C,C_old,None)

#Loop will run till the error becomes zero
while error!=0 :
#Assigning each value to its closest cluster
    for i in range(len(X)):
        distances=dist(X[i],C)
        cluster=np.argmin(distances)
        clusters[i]=cluster

# %%
#importing libraries
# %matplotlib inline
from copy import deepcopy
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize']=(16,9)
plt.style.use('ggplot')
data=pd.read_csv('C:/Users/Nischal Aryal/MachineLearning/Weather_Analysis/xclara.csv')
print(data.shape)
data.head()


#plotting cluster of data
f1=data ['Temperature Difference'].values
f2=data['Pressure Difference'].values
X=np.array(list(zip(f1,f2)))
plt.scatter(f1,f2,c='black',s=8)

#Euclidean Distance Calcultor
def dist(a,b,ax=1):
    return np.linalg.norm(a-b,axis=ax)

#Number of clsuters
k=3
#X coordinates of random centroids
C_x=np.random.randint(0,np.max(X)-20,size=k)

#Y coordinates of random centroids
C_y=np.random.randint(0,np.max(X)-20,size=k)
C=np.array(list(zip(C_x,C_y)), dtype=np.float32)
print(C)

#Plotting along with the Centroids
plt.scatter(f1,f2,c='#050505',s=7)
plt.scatter(C_x,C_y,marker='*',s=400,c='g')

#To store the value of centroid when it updates
C_old=np.zeros(C.shape)

#Clsuter labels(0,1,2)
clusters=np.zeros(len(X))

#Error Checking=Distance between new centroid and old centroid
error=dist(C,C_old,None)

#Loop will run till the error becomes zero
while error!=0 :
#Assigning each value to its closest cluster
    for i in range(len(X)):
        distances=dist(X[i],C)
        cluster=np.argmin(distances)
        clusters[i]=cluster
        #Storing the old centroid values
C_old=deepcopy(C)
#finding the new centroid by taking the average value
for i in range(k):
    points= [X[J] for j in range(len(x)) if clusters[j]==i]
    C[i]=np.mean(points,axis=0)
    error=dist(C,C_old,None)
colors=['r','g','b','y','c','m']
fig.ax=plt.subplots()

for i in range(k):
    points=np.array([X[J] for j in range(len(X)) if clusters[j]==i])
    ax.scatter(points[:,0],points[:,1],s=7,c=colors[i])
    ax.scatter(C[:,0],C[:,1],marker='*',s=400,c='#0505505')

# %%
#Storing the old centroid values
C_old=deepcopy(C)
#finding the new centroid by taking the average value
for i in range(k):
    points= [X[J] for j in range(len(x)) if clusters[j]==i]
    C[i]=np.mean(points,axis=0)
    error=dist(C,C_old,None)
colors=['r','g','b','y','c','m']
fig.ax=plt.subplots()

for i in range(k)
    points=np.array([X[J] for j in range(len(X)) if clusters[j]==i])
    ax.scatter(points[:,0],points[:,1],s=7,c=colors[i])
    ax.scatter(C[:,0],C[:,1],marker='*',s=400,c='#050505')

print(ax)
